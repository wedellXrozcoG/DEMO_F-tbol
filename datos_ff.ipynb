# %%
import pandas as pd
players_22 = pd.read_csv('players_22.csv', sep=',', na_values=[''], quotechar='"')
players_22
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_16608\1397760884.py:2: DtypeWarning: Columns (0: nation_position, 1: nation_logo_url) have mixed types. Specify dtype option on import or set low_memory=False.
#   players_22 = pd.read_csv('players_22.csv', sep=',', na_values=[''], quotechar='"')
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# ...

# %%
players_22.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19239 entries, 0 to 19238
# Data columns (total 110 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    sofifa_id                    19239 non-null  int64
#  1    player_url                   19239 non-null  str
#  2    short_name                   19239 non-null  str
#  3    long_name                    19239 non-null  str
#  4    player_positions             19239 non-null  str
#  5    overall                      19239 non-null  int64
#  6    potential                    19239 non-null  int64
#  7    value_eur                    19165 non-null  float64
#  8    wage_eur                     19178 non-null  float64
#  9    age                          19239 non-null  int64
#  10   dob                          19239 non-null  str
#  11   height_cm                    19239 non-null  int64
#  12   weight_kg                    19239 non-null  int64
# ...

# %%
df_22 = players_22[["short_name", "player_positions", "overall", "potential",
                   "value_eur", "age", "club_name", "league_name", "nationality_name",
                   "preferred_foot", "pace", "shooting", "passing", "dribbling",
                   "defending", "physic"]]

# %%
df_22
# Out:
#                short_name player_positions  overall  potential    value_eur  \
# 0                L. Messi       RW, ST, CF       93         93   78000000.0
# 1          R. Lewandowski               ST       92         92  119500000.0
# 2       Cristiano Ronaldo           ST, LW       91         91   45000000.0
# 3               Neymar Jr          LW, CAM       91         91  129000000.0
# 4            K. De Bruyne          CM, CAM       91         91  125500000.0
# ...                   ...              ...      ...        ...          ...
# 19234           Song Defu              CDM       47         52      70000.0
# 19235           C. Porter               CM       47         59     110000.0
# 19236            N. Logue               CM       47         55     100000.0
# 19237           L. Rudden               ST       47         60     110000.0
# 19238  E. Lalchhanchhuaha              CAM       47         60     110000.0
#
# ...

# %%
df_22.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19239 entries, 0 to 19238
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   short_name        19239 non-null  str
#  1   player_positions  19239 non-null  str
#  2   overall           19239 non-null  int64
#  3   potential         19239 non-null  int64
#  4   value_eur         19165 non-null  float64
#  5   age               19239 non-null  int64
#  6   club_name         19178 non-null  str
#  7   league_name       19178 non-null  str
#  8   nationality_name  19239 non-null  str
#  9   preferred_foot    19239 non-null  str
#  10  pace              17107 non-null  float64
#  11  shooting          17107 non-null  float64
#  12  passing           17107 non-null  float64
#  13  dribbling         17107 non-null  float64
#  14  defending         17107 non-null  float64
#  15  physic            17107 non-null  float64
# dtypes: float64(7), int64(3), str(6)
# ...

# %%
df_22.isnull().sum()
# Out:
# short_name             0
# player_positions       0
# overall                0
# potential              0
# value_eur             74
# age                    0
# club_name             61
# league_name           61
# nationality_name       0
# preferred_foot         0
# pace                2132
# shooting            2132
# passing             2132
# dribbling           2132
# defending           2132
# physic              2132
# dtype: int64

# %%
df_limpio_22 = df_22.dropna()

# %%
df_limpio_22.isnull().sum()
# Out:
# short_name          0
# player_positions    0
# overall             0
# potential           0
# value_eur           0
# age                 0
# club_name           0
# league_name         0
# nationality_name    0
# preferred_foot      0
# pace                0
# shooting            0
# passing             0
# dribbling           0
# defending           0
# physic              0
# dtype: int64

# %%
df_limpio_22.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 17041 entries, 0 to 19238
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   short_name        17041 non-null  str
#  1   player_positions  17041 non-null  str
#  2   overall           17041 non-null  int64
#  3   potential         17041 non-null  int64
#  4   value_eur         17041 non-null  float64
#  5   age               17041 non-null  int64
#  6   club_name         17041 non-null  str
#  7   league_name       17041 non-null  str
#  8   nationality_name  17041 non-null  str
#  9   preferred_foot    17041 non-null  str
#  10  pace              17041 non-null  float64
#  11  shooting          17041 non-null  float64
#  12  passing           17041 non-null  float64
#  13  dribbling         17041 non-null  float64
#  14  defending         17041 non-null  float64
#  15  physic            17041 non-null  float64
# dtypes: float64(7), int64(3), str(6)
# ...
